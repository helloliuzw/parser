# %%
d = {'一般院校':False,'双一流大学':False,'海外名校':False,'本科':False,'硕士':False,'博士':False}

print((d.items()))
# Out:
# dict_items([('一般院校', False), ('双一流大学', False), ('海外名校', False), ('本科', False), ('硕士', False), ('博士', False)])

# %%
print(d)
d['一般院校'] = True
print(d)
# Out:
# {'一般院校': False, '双一流大学': False, '海外名校': False, '本科': False, '硕士': False, '博士': False}
# {'一般院校': True, '双一流大学': False, '海外名校': False, '本科': False, '硕士': False, '博士': False}

# %%
class LabelClassifier:
    """
    base class for label classifier

    --------
    Parameter:
        label_dict: a map from integer to string label
    """
    def __init__(self,label_dict_path='data/labels.txt'):
        self.labeldict = {}  # dictionary that maps int to label text
        self.labeldictR = {} # maps label text to int
        self.load_label_dict(label_dict_path)
        #print(self.labeldictR)

    def load_label_dict(self,filename):
        with open(filename,encoding='UTF-8') as f:
            data = f.read().splitlines()
        self.labeldict = { i:a.split('\t')[0] for (i,a) in enumerate(data)}
        self.labeldictR = { a:i  for (i,a) in self.labeldict.items()}
        
zw = LabelClassifier()
print(zw.labeldict)
print(zw.labeldictR)
# Out:
# ['市委委员\t职位与职称', '市委候补委员\t职位与职称', '市人大常委\t职位与职称', '省政协委员\t职位与职称', '市政协委员\t职位与职称', '全国人大代表\t职位与职称', '省人大代表\t职位与职称', '全国党代表\t职位与职称', '省党代表\t职位与职称', '班子成员\t职位与职称', '正局正职\t职位与职称', '正局实职\t职位与职称', '副局实职\t职位与职称', '正处实职（市管）\t职位与职称', '街道党工委书记\t职位与职称', '街道办主任\t职位与职称', '一级巡视员\t职位与职称', '二级巡视员\t职位与职称', '一级调研员（副局级）\t职位与职称', '一级调研员\t职位与职称', '适应期\t职位属性', '破格提拔\t职位属性', '公选干部\t职位属性', '专项工作经历\t经历', '挂职经历\t经历', '中央部委经历\t经历', '省级单位经历\t经历', '央企经历\t经历', '国企经历\t经历', '民企经历\t经历', '外企经历\t经历', '事业单位经历\t经历', '高校科研院所经历\t经历', '境外工作经历\t经历', '应急管理经历\t经历', '金融从业经历\t经历', '产业部门经历\t经历', '市直部门一把手经历\t经历', '各区党政正职经历\t经历', '镇街工作经历\t经历', '镇街党政正职经历\t经历', '本市领导\t机构类别', '本市人大直属\t机构类别', '本市政府直属\t机构类别', '本市委直属\t机构类别', '本市政协直属\t机构类别', '本市法院与检察院\t机构类别', '本市事业单位与国企\t机构类别', '本市区政府部门\t机构类别', '市外政府部门\t机构类别', '市外事业单位\t机构类别', '市外企业单位\t机构类别']
# ...

# %% [markdown]
# # Test Json

# %%
import json
import lolviz as lz

# %%
'''stus={'xiaojun':123456,'xiaohei':'7890','lrx':'111111'}
f = open('stus2.json','w',encoding='utf-8')
json.dump(stus,f)
f.close()'''

# %%
'''f = open('stus2.json',encoding="utf-8")
user_dic = json.load(f)
f.close()
print(type(user_dic))
print(user_dic)'''
# Out:
# <class 'dict'>
# {'xiaojun': 123456, 'xiaohei': '7890', 'lrx': '111111'}

# %%
group_demo = {'isexist':['judger1'],'remove':['judger2'],'default':'label1','label2':['judger3','judger4']}
g = lz.objviz(group_demo)
print(type(g))
# int(g.source)
g.view()
# Out:
# <class 'graphviz.files.Source'>
# 'Source.gv.pdf'

# %%
school= {'isexist':['大学','学院','学校','分校'],'default':'一般院校','双一流大学':['清华','北大','北京大学']}
police = {'isexist':['公安','派出所','刑警'],'default':'公安'}
grade = {'isexist':['大学','学院','学校','分校'],'default':'本科','硕士':['硕士'],'博士':['博士']}
#= {'isexist':[],'default':}

labelgroup = {'school':school,'police':police,'grade':grade}
print(labelgroup)
#g = lz.objviz(labelgroup)
#g.view()


f = open('labelgroup.json','w',encoding='utf-8')
json.dump(labelgroup,f,ensure_ascii=False)
f.close()
# Out:
# {'school': {'isexist': ['大学', '学院', '学校', '分校'], 'default': '一般院校', '双一流大学': ['清华', '北大', '北京大学']}, 'police': {'isexist': ['公安', '派出所', '刑警'], 'default': '公安'}, 'grade': {'isexist': ['大学', '学院', '学校', '分校'], 'default': '本科', '硕士': ['硕士'], '博士': ['博士']}}

# %%
f = open('labelgroup.json',encoding='utf-8')
user_dic = json.load(f)
f.close()
print(type(user_dic))
print(user_dic)
# Out:
# <class 'dict'>
# {'school': {'isexist': ['大学', '学院', '学校', '分校'], 'default': '一般院校', '双一流大学': ['清华', '北大', '北京大学']}, 'police': {'isexist': ['公安', '派出所', '刑警'], 'default': '公安'}, 'grade': {'isexist': ['大学', '学院', '学校', '分校'], 'default': '本科', '硕士': ['硕士'], '博士': ['博士']}}

# %% [markdown]
# # Formal

# %%
print('北京大学、中国人民大学、清华大学、北京航空航天大学、北京理工大学、中国农业大学、北京师范大学、中央民族大学、南开大学、天津大学、大连理工大学、吉林大学、哈尔滨工业大学、复旦大学、同济大学、上海交通大学、华东师范大学、南京大学、东南大学、浙江大学、中国科学技术大学、厦门大学、山东大学、中国海洋大学、武汉大学、华中科技大学、中南大学、中山大学、华南理工大学、四川大学、重庆大学、电子科技大学、西安交通大学、西北工业大学、兰州大学、国防科技大学、东北大学、郑州大学、湖南大学、云南大学、西北农林科技大学、新疆大学'.split('、'))
# Out:
# ['北京大学', '中国人民大学', '清华大学', '北京航空航天大学', '北京理工大学', '中国农业大学', '北京师范大学', '中央民族大学', '南开大学', '天津大学', '大连理工大学', '吉林大学', '哈尔滨工业大学', '复旦大学', '同济大学', '上海交通大学', '华东师范大学', '南京大学', '东南大学', '浙江大学', '中国科学技术大学', '厦门大学', '山东大学', '中国海洋大学', '武汉大学', '华中科技大学', '中南大学', '中山大学', '华南理工大学', '四川大学', '重庆大学', '电子科技大学', '西安交通大学', '西北工业大学', '兰州大学', '国防科技大学', '东北大学', '郑州大学', '湖南大学', '云南大学', '西北农林科技大学', '新疆大学']

# %%
zw = liu.split('\n')
zw = [item.split()[0] for i,item in enumerate(zw) if i%6==0]
zw = [item.split('（')[0] for item in zw]
zw = [item.split('(')[0] for item in zw]
print(len(zw))
print((zw))
# Out:
# 100
# ...

# %%
zw = ['麻省理工学院', '斯坦福大学', '哈佛大学', '加州理工大学', '牛津大学', '苏黎世联邦理工大学', '剑桥大学', '帝国理工学院', '芝加哥大学', '伦敦大学学院', '新加坡国立大学', '普林斯顿大学', '南洋理工大学', '洛桑联邦理工学院', '清华大学', '宾夕法尼亚大学', '耶鲁大学', '康奈尔大学', '哥伦比亚大学', '爱丁堡大学', '密歇根大学', '香港大学', '北京大学', '东京大学', '约翰霍普金斯大学', '多伦多大学', '香港科技大学', '曼彻斯特大学', '西北大学', '加州大学伯克利分校', '澳大利亚国立大学', '伦敦国王学院', '麦吉尔大学', '复旦大学', '纽约大学', '加州大学洛杉矶分校', '首尔国立大学', '京都大学', '韩国科学技术研究所', '悉尼大学', '墨尔本大学', '杜克大学', '香港中文大学', '新南威尔士大
', '罗蒙诺索夫莫斯科国立大学', '香港理工大学', '哥本哈根大学', '浦项科技大学', '格拉斯哥大学', '东北大学', '乔治亚理工学院', '奥克兰大学', '伊利诺伊大学香槟分校', 'Sorbonne', '鲁汶大学', '延世大学', '杜伦大学', '伯明翰大学', '成均馆大学', '赖斯大学', '南安普敦大学', '利兹大学', '西澳大学', '谢菲尔德大学', '中国科技大学', '北卡罗来纳大学教堂山', '圣安德鲁斯大学', '隆德大学', '皇家理工学院', '诺丁汉大学', '墨西哥国立自治大学']}
education = {'isexist':['教育','教授','讲师','教师'],'remove':['公安'],'default':'教育'}
police = {'isexist':['公安','派出所','刑警'],'remove':['公司'],'default':'公安'}
HKMO = {'isexist':['香港','澳门'],'remove':[],'default':'港澳外事'}
tech = {'isexist':['科技','科研','研究院','研究员','科创'],'remove':['行政'],'default':'科技技术'}
environment = {'isexist':['环保','卫生','清洁'],'remove':[],'default':'卫生环保'}
law = {'isexist':['法律','法院','纪检','纪律检查','监察','检查院','律师','巡视组'],'remove':[],'default':'法务纪检'}
transport = {'isexist':['交通','运输','交管','交警','车管'],'remove':[],'default':'交通运输'}
grassrootswork = {'isexist':['街道','社区','小区'],'remove':[],'default':'基层工作'}

# %%
rule_label = {'school':school,'education':education,'police':police,'HKMO':HKMO,'tech':tech,'environment':environment,'law':law,'transport':transport,'grassrootswork':grassrootswork}
print(rule_label)

f = open('rule_label.json','w',encoding='utf-8')
json.dump(rule_label,f,ensure_ascii=False)
f.close()
# Out:
# {'school': {'isexist': ['大学', '学院', '学校', '分校'], 'remove': ['教授', '讲师', '教师', '主任'], 'default': '一般院校', '双一流大学': ['北京大学', '中国人民大学', '清华大学', '北京航空航天大学', '北京理工大学', '中国农业大学', '北京师范大学', '中央民族大学', '南开大学', '天津大学', '大连理工大学', '吉林大学', '哈尔滨工业大学', '复旦大学', '同济大学', '上海交通大学', '华东师范大学', '南京大学', '东南大学', '浙江大学', '中国科学技术大学', '厦门大学', '山东大学', '中国海洋大学', '武汉大学', '华中科技大学', '中南大学', '中山大学', '华南理工大学', '四川大学', '重庆大学', '电子科技大学', '西安交通大学', '西北工业大学', '兰州大学', '国防科技大学', '东北大学', '郑州大学', '湖南大学', '云南大学', '西北农林科技大学', '新疆大学', '北大', '清华', '北航', '北理工', '北师大', '哈工大', '复旦', '同济', '浙大', '中科大', '厦大'], '海外名校': ['麻省理工学院', '斯坦福大学', '哈佛大学', '加州理工大学', '牛津大学', '苏黎世联邦理工大学', '剑桥大学', '帝国理工学院', '芝加哥大学', '伦敦大学学院', '新加坡国立大学', '普林斯顿大学', '南洋理工大学', '洛桑联邦理工学院', '清华大学', '宾夕法尼亚大学', '耶鲁大学', '康奈尔大学', '哥伦比亚大学', '爱丁堡大学', '密歇根大学', '香港大学', '北京大学', '东京大学', '约翰霍普金斯大学', '多伦多大学', '香港科技大学', '曼彻斯特大学', '西北大学', '加州大学伯克利分校', '澳大利亚国立大学', '伦敦国王学院', '麦吉尔大学', '复旦大学', '纽约大学', '加州大学洛杉矶分校', '首尔国立大学', '京都大学', '韩国科学技术研究所', '悉尼大学', '墨尔本大学', '杜克大学', '香港中文大学', '新南威尔士大学'
# ...

# %%
f = open('rule_label.json',encoding='utf-8')
user_dic = json.load(f)
f.close()
print(type(user_dic))
print(user_dic)
# Out:
# <class 'dict'>
# ...

# %%
lz.objviz(user_dic)
